# %% [markdown]
# # TASK-1

# %%
import pandas as pd

# %%
df = pd.read_csv("Sales Data.csv")
df
# Out:
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0                2    194097        27in FHD Monitor                 1
# 1                5    194100                  iPhone                 1
# 2                8    194103        27in FHD Monitor                 1
# 3               15    194110            Google Phone                 1
# 4               16    194110        Wired Headphones                 1
# ...            ...       ...                     ...               ...
# 185945       11651    259325    USB-C Charging Cable                 1
# 185946       11654    259328        Wired Headphones                 1
# 185947       11656    259330   AA Batteries (4-pack)                 2
# 185948       11663    259336  AAA Batteries (4-pack)                 3
# 185949       11667    259340   AA Batteries (4-pack)                 2
#
#         Price Each        Order Date  \
# 0           149.99  24-05-2019 11:36
# ...

# %%
df.isnull()
# Out:
#         Unnamed: 0  Order ID  Product  Quantity Ordered  Price Each  \
# 0            False     False    False             False       False
# 1            False     False    False             False       False
# 2            False     False    False             False       False
# 3            False     False    False             False       False
# 4            False     False    False             False       False
# ...            ...       ...      ...               ...         ...
# 185945       False     False    False             False       False
# 185946       False     False    False             False       False
# 185947       False     False    False             False       False
# 185948       False     False    False             False       False
# 185949       False     False    False             False       False
#
#         Order Date  Purchase Address  Month  Sales   City   Hour    Day  \
# 0            False             False  False  False  False  False  False
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# Order ID              int64
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                 int64
# Sales               float64
# City                 object
# Hour                  int64
# Day                  object
# Month.1              object
# Year                  int64
# Quarter              object
# dtype: object

# %%
#Aggregate Functions

# %%
df['Sales'].sum()
# Out:
# 34492035.97

# %%
df['Quantity Ordered'].max()
# Out:
# 9

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9480\1722919639.py:1: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Order Date']=pd.to_datetime(df['Order Date'])

# %%
# to display a particular field

# %%
df['Product']=="Wired Headphones"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 185945    False
# 185946     True
# 185947    False
# 185948    False
# 185949    False
# Name: Product, Length: 185950, dtype: bool

# %%
#To Fetch the Unique Values

# %%
df['City'].unique()
# Out:
# array([' New York City', ' San Francisco', ' Seattle', ' Los Angeles',
#        ' Atlanta', ' Portland', ' Boston', ' Austin', ' Dallas'],
#       dtype=object)

# %%
#Using AND

# %%
cond1 = df['Product'] == "iPhone"
cond2 = df['Sales'] > 600
df[cond1 & cond2].head()
# Out:
#     Unnamed: 0  Order ID Product  Quantity Ordered  Price Each  \
# 1            5    194100  iPhone                 1       700.0
# 16          97    194186  iPhone                 1       700.0
# 19         116    194203  iPhone                 1       700.0
# 37         241    194320  iPhone                 1       700.0
# 40         249    194327  iPhone                 1       700.0
#
#             Order Date                          Purchase Address  Month  \
# 1  2019-05-10 19:44:00  81 Jefferson St, San Francisco, CA 94016      5
# 16 2019-05-10 22:44:00          495 Wilson St, Seattle, WA 98101      5
# 19 2019-05-10 16:38:00          339 Cedar St, Portland, OR 97035      5
# 37 2019-05-17 05:53:00     180 Adams St, New York City, NY 10001      5
# 40 2019-05-10 17:42:00              984 6th St, Austin, TX 73301      5
#
#     Sales            City  Hour     Day Month.1  Year Quarter
# 1   700.0   San Francisco    19  Friday     May  2019      Q2
# ...

# %%
#Using OR

# %%
cond1 = df['City'] == "New York City"
cond2 = df['Day'] == "Sunday"
df[cond1 | cond2].head()
# Out:
#        Unnamed: 0  Order ID                   Product  Quantity Ordered  \
# 79286           1    194096     AA Batteries (4-pack)                 1
# 79287          11    194106      USB-C Charging Cable                 1
# 79288          12    194107    34in Ultrawide Monitor                 1
# 79289          22    194116  Lightning Charging Cable                 1
# 79290          23    194117  Lightning Charging Cable                 1
#
#        Price Each          Order Date  \
# 79286        3.84 2019-05-19 14:43:00
# 79287       11.95 2019-05-12 10:07:00
# 79288      379.99 2019-05-19 17:52:00
# 79289       14.95 2019-05-19 23:19:00
# 79290       14.95 2019-05-12 08:44:00
#
#                               Purchase Address  Month   Sales            City  \
# 79286          844 Walnut St, Dallas, TX 75001      5    3.84          Dallas
# 79287  261 Jackson St, San Francisco, CA 94016      5   11.95   San Francisco
# ...

# %%
cond1 = df['Sales'].between (150,700)
df[cond1].head()
# Out:
#    Unnamed: 0  Order ID                   Product  Quantity Ordered  \
# 1           5    194100                    iPhone                 1
# 3          15    194110              Google Phone                 1
# 5          19    194113  Apple Airpods Headphones                 1
# 6          27    194121                  LG Dryer                 1
# 7          29    194123  Apple Airpods Headphones                 1
#
#    Price Each          Order Date                          Purchase Address  \
# 1       700.0 2019-05-10 19:44:00  81 Jefferson St, San Francisco, CA 94016
# 3       600.0 2019-05-31 18:07:00        498 14th St, Los Angeles, CA 90001
# 5       150.0 2019-05-10 22:33:00        29 Adams St, Los Angeles, CA 90001
# 6       600.0 2019-05-10 20:41:00        911 Hill St, Los Angeles, CA 90001
# 7       150.0 2019-05-24 00:34:00          546 Meadow St, Atlanta, GA 30301
#
#    Month  Sales            City  Hour     Day Month.1  Year Quarter
# ...

# %%
cond1= df.groupby ('City')['Quantity Ordered'].count()
cond1
# Out:
# City
#  Atlanta          14881
#  Austin            9905
#  Boston           19934
#  Dallas           14820
#  Los Angeles      29605
#  New York City    24876
#  Portland         12465
#  San Francisco    44732
#  Seattle          14732
# Name: Quantity Ordered, dtype: int64

# %%
df['Product'].unique()
# Out:
# array(['27in FHD Monitor', 'iPhone', 'Google Phone', 'Wired Headphones',
#        'Apple Airpods Headphones', 'LG Dryer', 'AAA Batteries (4-pack)',
#        'Bose SoundSport Headphones', 'Lightning Charging Cable',
#        '20in Monitor', 'AA Batteries (4-pack)', 'Flatscreen TV',
#        'USB-C Charging Cable', 'ThinkPad Laptop',
#        '27in 4K Gaming Monitor', 'Macbook Pro Laptop', 'Vareebadd Phone',
#        'LG Washing Machine', '34in Ultrawide Monitor'], dtype=object)

# %%
df['Sales'].unique()
# Out:
# array([1.49990e+02, 7.00000e+02, 6.00000e+02, 1.19900e+01, 1.50000e+02,
#        5.98000e+00, 9.99900e+01, 1.49500e+01, 1.09990e+02, 3.84000e+00,
#        3.00000e+02, 1.19500e+01, 9.99990e+02, 2.99000e+01, 3.89990e+02,
#        1.70000e+03, 2.99000e+00, 8.97000e+00, 7.68000e+00, 2.39000e+01,
#        4.00000e+02, 2.39800e+01, 5.98000e+01, 3.79990e+02, 1.15200e+01,
#        1.79400e+01, 1.19600e+01, 3.58500e+01, 3.59700e+01, 4.48500e+01,
#        1.53600e+01, 1.99980e+02, 2.09300e+01, 7.59980e+02, 2.19980e+02,
#        8.00000e+02, 1.92000e+01, 7.79980e+02, 4.78000e+01, 2.39200e+01,
#        2.68800e+01, 2.99980e+02, 2.30400e+01, 1.20000e+03, 3.40000e+03,
#        5.97500e+01, 2.69100e+01, 2.99970e+02, 1.40000e+03, 4.79600e+01,
#        1.99998e+03, 7.17000e+01, 4.50000e+02])

# %%
df['City'].unique()
# Out:
# array([' New York City', ' San Francisco', ' Seattle', ' Los Angeles',
#        ' Atlanta', ' Portland', ' Boston', ' Austin', ' Dallas'],
#       dtype=object)

# %% [markdown]
# # For Visualization

# %%
import matplotlib.pyplot as plt
a=df.set_index('Order ID').head(10)
a
a.plot()
plt.title('Order ID')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.plot(kind = 'hist' , x= 'Product', y = 'Sales')
plt.title('Sum of Sales by Product')
plt.show()
