# %% [markdown]
# # TASK - 4

# %%
import pandas as pd

# %%
df = pd.read_csv("Social Media.csv")
df
# Out:
#      s.no  Unnamed: 0                                               Text  \
# 0       0           0   Enjoying a beautiful day at the park!        ...
# 1       1           1   Traffic was terrible this morning.           ...
# 2       2           2   Just finished an amazing workout! 💪          ...
# 3       3           3   Excited about the upcoming weekend getaway!  ...
# 4       4           4   Trying out a new recipe for dinner tonight.  ...
# ..    ...         ...                                                ...
# 727   728         732  Collaborating on a science project that receiv...
# 728   729         733  Attending a surprise birthday party organized ...
# 729   730         734  Successfully fundraising for a school charity ...
# 730   731         735  Participating in a multicultural festival, cel...
# 731   732         736  Organizing a virtual talent show during challe...
#
#        Sentiment         Timestamp                                   User  \
# ...

# %%
df.dtypes
# Out:
# s.no           int64
# Unnamed: 0     int64
# Text          object
# Sentiment     object
# Timestamp     object
# User          object
# Platform      object
# Hashtags      object
# Retweets       int64
# Likes          int64
# Country       object
# Year           int64
# Month          int64
# Day            int64
# Hour           int64
# dtype: object

# %%
df['Likes'].sum()
# Out:
# 31404

# %%
df['Hour'].max()
# Out:
# 23

# %%
df['Country'].count()
# Out:
# 732

# %%
df['Sentiment'] = "Positive"
df
# Out:
#      s.no  Unnamed: 0                                               Text  \
# 0       0           0   Enjoying a beautiful day at the park!        ...
# 1       1           1   Traffic was terrible this morning.           ...
# 2       2           2   Just finished an amazing workout! 💪          ...
# 3       3           3   Excited about the upcoming weekend getaway!  ...
# 4       4           4   Trying out a new recipe for dinner tonight.  ...
# ..    ...         ...                                                ...
# 727   728         732  Collaborating on a science project that receiv...
# 728   729         733  Attending a surprise birthday party organized ...
# 729   730         734  Successfully fundraising for a school charity ...
# 730   731         735  Participating in a multicultural festival, cel...
# 731   732         736  Organizing a virtual talent show during challe...
#
#     Sentiment         Timestamp                                   User  \
# ...

# %%
df['Platform'].unique()
# Out:
# array([' Twitter  ', ' Instagram ', ' Facebook ', ' Twitter '],
#       dtype=object)

# %%
cond1 = df['Country'] == "USA"
cond2 = df['Day'] >= 15
df[cond1 & cond2]
# Out:
#      s.no  Unnamed: 0                                               Text  \
# 10     10          10   Just published a new blog post. Check it out!...
# 18     18          18   Attending a virtual conference on AI.        ...
# 21     21          21   Exploring the world of virtual reality.      ...
# 33     34          35   Feeling inspired after attending a workshop. ...
# 39     40          41   Excited about the upcoming gaming tournament....
# 62     63          65   Sending affectionate vibes to all my follower...
# 68     69          71   Anticipating a thrilling adventure in the com...
# 86     87          89   Sending affectionate vibes to friends and fam...
# 128   129         131   Empowerment through learning and personal gro...
#
#     Sentiment        Timestamp                User     Platform  \
# 10   Positive  1/17/2023 15:15       BloggerX        Instagram
# 18   Positive  1/20/2023 11:30      TechConference    Facebook
# ...

# %%
df['Retweets'].max()
# Out:
# 40

# %%
cond1 = df['Retweets'].between(30,40)
df[cond1]
# Out:
#      s.no  Unnamed: 0                                               Text  \
# 8       8           8   Political discussions heating up on the timel...
# 22     22          22   Productive day ticking off my to-do list.    ...
# 32     33          34   Coding a new project with enthusiasm.        ...
# 39     40          41   Excited about the upcoming gaming tournament....
# 56     57          59   Pure happiness: celebrating a loved one's ach...
# ..    ...         ...                                                ...
# 646   647         651  Daydreaming about the upcoming prom. The dress...
# 649   650         654  Trying to master the perfect kickflip on my sk...
# 654   655         659  Got my hands on the latest fantasy novel. Divi...
# 657   658         662  Sneaking snacks into class like a pro. The art...
# 661   662         666  Tried to impress my crush with a smooth conver...
#
#     Sentiment        Timestamp                         User     Platform  \
# ...

# %%
cond1 = df.groupby ('Country')['Day'].count()
cond1.tail()
# Out:
# Country
#  USA                   20
#  USA                    1
#  USA                    4
#  USA                    9
# USA                     9
# Name: Day, dtype: int64

# %%
df['Hashtags'] == "#Happiness #Celebration".
count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df['Hashtags'] == "#Happiness #Celebration".count()
#
# TypeError: count() takes at least 1 argument (0 given)
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\USER\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# ...

# %% [markdown]
# # FOR VISUALIZATION

# %%
import matplotlib.pyplot as plt
a=df.set_index('Retweets').head(10)
a
a.plot()
plt.title('Platform')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.plot(kind = 'hist' , x= 'Platform', y = 'Likes')
plt.title('Sum of Likes by Platform')
plt.show()
